# %%
from stable_baselines.common.policies import MlpLstmPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
import pandas as pd
import gym
from gym import spaces
import numpy as np
from scipy.stats import truncnorm
import pandas as pd
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
data = pd.read_csv('2019_LAPLMG1_7_B2.csv')
days = pd.unique(data['Date'])

# %%
env = gym.make('gym_custom:foo-v0', data=data)
for episode in range(1000): 
    #env = DummyVecEnv([lambda: CustomEnv(prices)])
    model =PPO2(MlpLstmPolicy, env, verbose=1, nminibatches=1)
    model.learn(total_timesteps=300)
    obs = env.reset()
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\policies.py:420: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\ppo2\ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\ppo2\ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\ppo2\ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\ppo2\ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From c:\users\willc\anaconda3\envs\projectx\lib\site-packages\stable_baselines\ppo2\ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Initializing on 2019-07-28
# --------------------------------------
# | approxkl           | 1.8778028e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 28            |
# | n_updates          | 1             |
# | policy_entropy     | 1.091642      |
# | policy_loss        | 0.00039656262 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 1.4488177e+16 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.170239e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 240           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0904393     |
# | policy_loss        | 0.00012817653 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.54          |
# | total_timesteps    | 256           |
# | value_loss         | 1.3547833e+18 |
# --------------------------------------
# Initializing on 2019-03-18
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-08-03
# --------------------------------------
# | approxkl           | 4.2477368e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 30            |
# | n_updates          | 1             |
# | policy_entropy     | 1.0985293     |
# | policy_loss        | 2.8230192e-05 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 1.2749315e+16 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.6113924e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 253           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0983284     |
# | policy_loss        | 0.0003925052  |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.14          |
# | total_timesteps    | 256           |
# | value_loss         | 1.3354278e+19 |
# --------------------------------------
# Initializing on 2019-02-04
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-09-06
# --------------------------------------
# | approxkl           | 6.071621e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 30            |
# | n_updates          | 1             |
# | policy_entropy     | 1.0974138     |
# | policy_loss        | -8.913339e-07 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 1.8237496e+16 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.5293037e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0              |
# | fps                | 197            |
# | n_updates          | 2              |
# | policy_entropy     | 1.0968833      |
# | policy_loss        | 0.00045592198  |
# | serial_timesteps   | 256            |
# | time_elapsed       | 4.24           |
# | total_timesteps    | 256            |
# | value_loss         | 1.00420754e+18 |
# ---------------------------------------
# Initializing on 2019-07-27
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-03-23
# ---------------------------------------
# | approxkl           | 7.3150804e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0              |
# | fps                | 31             |
# | n_updates          | 1              |
# | policy_entropy     | 1.0937543      |
# | policy_loss        | -0.00022743664 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 0              |
# | total_timesteps    | 128            |
# | value_loss         | 1.1878224e+16  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.192556e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 234           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0959563     |
# | policy_loss        | 0.00017802417 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.03          |
# | total_timesteps    | 256           |
# | value_loss         | 1.4533248e+17 |
# --------------------------------------
# Initializing on 2019-01-04
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-02-05
# --------------------------------------
# | approxkl           | 4.4984015e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 29            |
# | n_updates          | 1             |
# | policy_entropy     | 1.097745      |
# | policy_loss        | 0.00018677556 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 1.7402454e+16 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.339059e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 229           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0970691     |
# | policy_loss        | 0.00069778226 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.29          |
# | total_timesteps    | 256           |
# | value_loss         | 2.2624838e+18 |
# --------------------------------------
# Initializing on 2019-12-23
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-05-28
# -------------------------------------------
# | approxkl           | 3.5941248e-05      |
# | clipfrac           | 0.0                |
# | explained_variance | 0                  |
# | fps                | 30                 |
# | n_updates          | 1                  |
# | policy_entropy     | 1.0965202          |
# | policy_loss        | -0.00068246986     |
# | serial_timesteps   | 128                |
# | time_elapsed       | 0                  |
# | total_timesteps    | 128                |
# | value_loss         | 2048217800000000.0 |
# -------------------------------------------
# --------------------------------------
# | approxkl           | 6.118571e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 255           |
# | n_updates          | 2             |
# | policy_entropy     | 1.096698      |
# | policy_loss        | 0.0005824035  |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.16          |
# | total_timesteps    | 256           |
# | value_loss         | 2.4040933e+16 |
# --------------------------------------
# Initializing on 2019-12-19
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-05-12
# ------------------------------------------
# | approxkl           | 2.1509008e-05     |
# | clipfrac           | 0.0               |
# | explained_variance | 0                 |
# | fps                | 30                |
# | n_updates          | 1                 |
# | policy_entropy     | 1.0960872         |
# | policy_loss        | 0.0008447263      |
# | serial_timesteps   | 128               |
# | time_elapsed       | 0                 |
# | total_timesteps    | 128               |
# | value_loss         | 700202950000000.0 |
# ------------------------------------------
# --------------------------------------
# | approxkl           | 3.586719e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 264           |
# | n_updates          | 2             |
# | policy_entropy     | 1.096652      |
# | policy_loss        | 9.3287556e-05 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.17          |
# | total_timesteps    | 256           |
# | value_loss         | 1.2491202e+16 |
# --------------------------------------
# Initializing on 2019-05-03
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-02-12
# ---------------------------------------
# | approxkl           | 6.0904777e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0              |
# | fps                | 28             |
# | n_updates          | 1              |
# | policy_entropy     | 1.0972717      |
# | policy_loss        | -0.00024730276 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 0              |
# | total_timesteps    | 128            |
# | value_loss         | 2.5495574e+16  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.1773037e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0             |
# | fps                | 252           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0977349     |
# | policy_loss        | 0.00034363475 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 4.51          |
# | total_timesteps    | 256           |
# | value_loss         | 1.2365473e+19 |
# --------------------------------------
# Initializing on 2019-01-05
# Wrapping the env in a DummyVecEnv.
# Initializing on 2019-12-08
# -------------------------------------------
# | approxkl           | 0.000103243525     |
# | clipfrac           | 0.0                |
# | explained_variance | 0                  |
# | fps                | 30                 |
# | n_updates          | 1                  |
# | policy_entropy     | 1.0962037          |
# | policy_loss        | 0.0003026988       |
# | serial_timesteps   | 128                |
# | time_elapsed       | 0                  |
# | total_timesteps    | 128                |
# | value_loss         | 9016975000000000.0 |
# -------------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001462921   |
# | clipfrac           | 0.0            |
# | explained_variance | 0              |
# | fps                | 238            |
# | n_updates          | 2              |
# | policy_entropy     | 1.0943844      |
# | policy_loss        | -0.00084058195 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 4.27           |
# | total_timesteps    | 256            |
# | value_loss         | 1.14097504e+18 |
# ---------------------------------------
# Initializing on 2019-09-21
# Wrapping the env in a DummyVecEnv.

# %%
days = pd.unique(data['Date'])

# %%
day = np.random.choice(days)
print(f"Initializing on {day}")
day_data = data[data["Date"]==day]
# Out:
# Initializing on 2019-08-25

# %%
day_data.reset_index()['Value'][0]
# Out:
# 26.256590000000003

# %%
data[data["Date"]==day]
